# %%
type("hello world!")
# Out:
# str

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
s1 = "Hello"
s2 = 'World'
print(s1)
# Out:
# Hello

# %%
single_quoted = 'Hello, World!'
len(single_quoted)
# Out:
# 13

# %%
print(single_quoted[12])
# Out:
# !

# %%
s = "hello world"

s.upper()    # "HELLO WORLD"
s.lower()    # "hello world"
s.title()    # "Hello World"
s.capitalize()  # "Hello world"
#note the last output as we didn't include any print commands
# Out:
# 'Hello world'

# %%
s = "  hello  "
print(s)
s.strip()   # "hello"
s.lstrip()  # "hello  "
s.rstrip()  # "  hello"
# Out:
#   hello
# '  hello'

# %%
s = "a,b,c"

s.split(",")
# ['a', 'b', 'c']

"-".join(['a', 'b', 'c'])
# "a-b-c"
s.split(",")
#outputs the list separated by brackets
# Out:
# ['a', 'b', 'c']

# %%
a = "Hello"
b = "World"

result = a + " " + b
print(result)
# Hello World
# Out:
# Hello World

# %%
print("Hi" * 3)
# HiHiHi
# Out:
# HiHiHi

# %%
name = "Hareth"
age = 30

print("My name is " + name + " and I am " + str(age) + " years old")
# Out:
# My name is Hareth and I am 30 years old

# %%
name = "Ali"
age = 20

print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Ali and I am 20 years old

# %%
print("C:\\Users\\Hareth")
#note the slightly different olor as an escape character
# Out:
# C:\Users\Hareth

# %%
#question 6/7 in course
data = "apple,banana,cherry"
result = data.split(",")
print(result)
# Out:
# ['apple', 'banana', 'cherry']

# %%
years=[2019,2020,2021]
age = len(years)

result = "Adult" if age >= 18 else "Minor"
print(result)
# Out:
# Minor

# %%
name = "Hareth"

if name == "Hareth":
    print("Hello Hareth")
# Out:
# Hello Hareth

# %%
num = 7

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# 🔁 What are loops?
#
# Loops let you repeat code multiple times.

# %%
names = ["Ali", "Sara", "Omar"]

for name in names:
    print("Weird")
# Out:
# Weird
# Weird
# Weird

# %%
for i in range(5):
    print(i);
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#suppose I wanted to just print 'weird' three times, how would I modify this code like we did earlier?
i=0
while i<3:
  print("Weird")
  i += 1
# Out:
# Weird
# Weird
# Weird

# %%
for i in range(3):
    print("Weird")
# Out:
# Weird
# Weird
# Weird

# %% [markdown]
# Functions

# %%
def addnumbers(a,b):
  return a+b

# %%
#trial to see it accepts string arguments
addnumbers("Hello ", "Bob!")
# Out:
# 'Hello Bob!'

# %%
def multiply(a,b=2):
  return a*b

# %%
print(multiply(3))
# Out:
# 6

# %% [markdown]
# Functions Local vs Global Variables Example

# %%
def my_function():
  x = 10 # Local variable
  print(x)

# %%
#There is nothing in that function that keeps that value 'x' elsewhere
my_function()
# Out:
# 10

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4020/1353120783.py in <cell line: 0>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4020/32546335.py in <cell line: 0>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
#let's modify the code
def my_function():
  x = 10 # Local variable
  print(x)
  return(x)
